# %% [markdown]
# # Popularity-Based Filtering

# %% [markdown]
# ### Load data

# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
credits = pd.read_csv('credits.csv')
ratings = pd.read_csv('ratings.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ### Calculate a weighted rating for movies

# %% [markdown]
# WR = (v/(v+m)) x R + (m /(v+m)) x C

# %% [markdown]
# v - number of votes for a movie

# %% [markdown]
# m - minimum number of votes required for a movie to be considered popular

# %% [markdown]
# R - average movie rating

# %% [markdown]
# C - average rating of all movies

# %%
m = movies['vote_count'].quantile(0.9)
C = movies['vote_average'].mean()

# %%
movies_filtered = movies.copy().loc[movies['vote_count'] >= m]
movies_filtered
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4291    1200000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 4300    1200000  [{"id": 80, "name": "Crime"}, {"id": 53, "name...
# 4302    1200000                    [{"id": 37, "name": "Western"}]
# 4337    1300000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 4602     350000                      [{"id": 18, "name": "Drama"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
def weighted_rating(df, m=m, C=C):
    R = df['vote_average']
    v = df['vote_count']
    wr = (v/(v+m))*R + (m/(v+m))*C
    return wr

# %%
movies_filtered['weighted_rating'] = movies.apply(weighted_rating, axis=1)
movies_filtered.sort_values('weighted_rating', ascending=False).head()
# Out:
#          budget                                             genres  \
# 1881   25000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 662    63000000                      [{"id": 18, "name": "Drama"}]
# 65    185000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3232    8000000  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 96    160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
#
#                                           homepage     id  \
# 1881                                           NaN    278
# 662     http://www.foxmovies.com/movies/fight-club    550
# 65    http://thedarkknight.warnerbros.com/dvdsite/    155
# 3232                                           NaN    680
# 96           http://inceptionmovie.warnerbros.com/  27205
#
#                                                keywords original_language  \
# 1881  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=02ac0b0e-67fe-4064-a060-b8c8223480ff' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
